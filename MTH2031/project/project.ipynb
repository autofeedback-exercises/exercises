# %% [markdown]
# # Project on Coupled Oscillators

# %% [markdown]
# Consider a three-mass two-spring system:
#
# <center><img src='https://raw.githubusercontent.com/autofeedback-exercises/exercises/testpip/MTH2031/project/springs.png' height=200 /></center>
#
# Assume the system is constrained to horizontal displacements only.
# Use Sympy in combination with NumPy and Scipy.
#
#   ## Steps
#   1. Write the expression for the kinetic and potential energies of the system.
#   2. Find the Lagrangian and thus the Hamiltonian as a Legendre transform
#   3. Write the EOMs from the Hamilton's equation.
#   4. Write the corresponding eigenproblem
#
# For the case of identical masses and spring constants
#
#   4. Find the normal modes symbolically (if possible) and numerically
#   5. Solve the Hamilton's equations numerically. Choose the initial conditions to excite either the single normal modes or a combination of modes.

# %%
# your code goes here

# %% [markdown]
# # Extension problems
#
# Only start working on the extension when your basic tasks code is working.
#
# If you need it, copy the relevant code from the basic tasks into here. This guarantees that while you are working on the extension, your basic tasks continue working as expected.
#
# A (non complete) list of possible extensions is given below
#
#   ## Possible extensions
#   1. Breaking the system symmetries (e.g. by changing the masses and spring's constants)
#   2. Relate results with the vibration of triatomic molecules
#   3. Varying the number of strings (e.g. consider a 3 mass 4 spring system)
#   4. Consider a 3-mass 3-spring system constrained to move on a circle
#   5. Allow displacements on a frictionless plane
#   6. Allow displacements on a frictionless plane and connect the terminal masses with a third spring
#   7. ...
