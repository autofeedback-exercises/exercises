# %% [markdown]
# # Lagrangian and Euler Lagrange equation with python

# %% [markdown]
# ## Instructions
#
# Consider a particle on an inclined plane. Here's the system with the choice of the system of coordinates and the generalised coordinate.
#
# <center><img src='https://raw.githubusercontent.com/autofeedback-exercises/exercises/testpip/MTH2031/weekly/plane.png' height=200 /></center>
#
#   ### Steps
#   1. Write $x$ and $y$ as a function of the generalised coordinate
#   2. Write the kinetic energy
#   3. Write the potential energy
#   4. Write the Lagrangian
#   5. Write the Lagrange equations
#   6. Check what you find against a pen-paper solution

# %%
# your code goes here
