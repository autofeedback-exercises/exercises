# %% [markdown]
# # Finding the turning points of a potential

# %% [markdown]
# # Instructions
#
# Consider the potential
# $$V=ax^2-bx^2+cx^3$$
#
# with $a=b=c=1$ and appropriate units. Energy is measured in Joules and distance in meters.
#
#
#   ## Steps
#   1.  Look back at the results for the equilibrium points from the previous week and define the interval of energies accordingly
#   2.  For each interval, choose a specific energy value of the total energy $E$ and:
#       * Find the turning points
#       * Plot $V$ and the value of the total energy and the turning points
#       * Plot the corresponding kinetic energy of the particle, showing as well the turning points
#       * Save the plots as figures
#
# Follow the example on Canvas as a guide through these steps.
#
# Follow the example as a guide through these steps.
#
# Once you have a figure, download it, insert it into a document and write a detailed figure caption. The resulting PDF should be submitted via the canvas assignment.
#
# You can use [this LaTeX template](https://www.overleaf.com/docs?snip_uri=https://github.com/abrown41/testoverleaf/raw/main/MTH2031_ex2.zip)

# %%
# your code goes here
