# %% [markdown]
# # Finding the Equilibrium points of a potential

# %% [markdown]
# Consider the potential
# $$V=ax^4 - bx^2+cx^3$$
#
# with $a=b=c=1$ and appropriate units. Energy is measured in Joules and distance in meters.
#
#   ## Steps
#   1. Find the equilibrium points
#   2. Classify the equilibrium points according to their stability
#   3. (Optional) Find the parabolic approximation about the stable equilibrium points.
#   4. Plot $V$ and the equilibrium points (and optionally: the parabolic approximation(s)).
#
# Follow the example as a guide through these steps.
#
# Once you have a figure, download it, insert it into a document and write a detailed figure caption. The resulting PDF should be submitted via the canvas assignment.
#
# You can use [this LaTeX template](https://www.overleaf.com/docs?snip_uri=https://github.com/abrown41/testoverleaf/raw/main/MTH2031.zip)

# %%
# your code goes here
